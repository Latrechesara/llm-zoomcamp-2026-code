# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# This reads the .env file
load_dotenv() 

# This automatically fetches the GROQ_API_KEY from your environment
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
assistant = RAGBase(index,client)

# %%
assistant.rag("I just discover the course can i still join ")
# Out:
# 'Yes, you can still join the course. However, to receive a certificate, you need to submit your project while submissions are still being accepted.'
