# %%
# %%bash
#
# PREFIX="https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main"
# wget ${PREFIX}/04-evaluation/code/evaluation_utils.py
# Out:
# <3>WSL (1863 - Relay) ERROR: CreateProcessCommon:800: execvpe(/bin/bash) failed: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nPREFIX="https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main"\nwget ${PREFIX}/04-evaluation/code/evaluation_utils.py\n')
#
# CalledProcessError: Command 'b'\nPREFIX="https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main"\nwget ${PREFIX}/04-evaluation/code/evaluation_utils.py\n'' returned non-zero exit status 1.

# %%
import urllib.request

# Define the base URL path
PREFIX = "https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code"

# Download ingest.py
urllib.request.urlretrieve(f"{PREFIX}/ingest.py", "ingest.py")
print("✅ ingest.py downloaded successfully!")

# Download rag_helper.py
urllib.request.urlretrieve(f"{PREFIX}/rag_helper.py", "rag_helper.py")
print("✅ rag_helper.py downloaded successfully!")
# Out:
# ✅ ingest.py downloaded successfully!
# ✅ rag_helper.py downloaded successfully!

# %%
import urllib.request

# Define the correct path for the evaluation module
PREFIX = "https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/04-evaluation/code"

# Download evaluation_utils.py
url = f"{PREFIX}/evaluation_utils.py"
output_file = "evaluation_utils.py"

urllib.request.urlretrieve(url, output_file)
print("✅ evaluation_utils.py downloaded successfully!")
# Out:
# ✅ evaluation_utils.py downloaded successfully!

# %%
print(123)
# Out:
# 123

# %%
# %%bash
# PREFIX="https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main"
#
# wget ${PREFIX}/01-agentic-rag/code/ingest.py
# wget ${PREFIX}/01-agentic-rag/code/rag_helper.py
# Out:
# --2026-07-14 11:43:58--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/ingest.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 738 [text/plain]
# Saving to: ‘ingest.py’
#
#      0K                                                       100% 42.7M=0s
#
# 2026-07-14 11:43:58 (42.7 MB/s) - ‘ingest.py’ saved [738/738]
#
# --2026-07-14 11:43:58--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...
